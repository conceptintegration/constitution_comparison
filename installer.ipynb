# %% [markdown]
# # Installer
#
#
# Requirements. Jupyter deployment

# %% [markdown]
# ## Run installation

# %%
# !pip install --upgrade --no-cache-dir gdown
print()

print('Downloading model file…')
# !gdown 'https://drive.google.com/uc?id=1_hgyH07a6IZkxWMGLvbl9Zmp3HWx4HQP'

print('Unzipping…')
# !unzip './model.zip'
print()

print('Clearing up…')

# !rm 'model.zip'
# !rm -r  './__MACOSX'

print('Downloading data…')
# !gdown 'https://drive.google.com/uc?id=1d1EBl_7H-CuUI3Y9-Ia_RfL0YF9tcXHW'

print('Unzipping…')
# !unzip './data.zip'
print()

print('Clearing up…')

# !rm 'data.zip'
# !rm -r  './__MACOSX'

print()
print('Finished')
